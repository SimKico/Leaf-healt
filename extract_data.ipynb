# %%
pip install mahotas
# Out:
# Requirement already satisfied: mahotas in /usr/local/lib/python3.7/dist-packages (1.4.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mahotas) (1.19.5)

# %%
#-----------------------------------
# GLOBAL FEATURE EXTRACTION
#-----------------------------------
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import mahotas 
import cv2
import os
import h5py

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -uq "/content/drive/My Drive/data.zip" -d "/content/drive/My Drive/PATH_TO_OUTPUT"

# %%
# get the training labels
train_path = "/content/drive/My Drive/PATH_TO_OUTPUT/data"
train_labels = os.listdir(train_path)
images_per_class       = 423 #change later to 423
fixed_size             = tuple((256, 256))
bins                   = 8

# %%
train_labels
# Out:
# ['Black_rot', 'Esca', 'Healthy', 'Leaf_blight']

# %%
# Converting each image to RGB from BGR format

def rgb_bgr(image):
    rgb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return rgb_img

# %%
# Conversion to HSV image format from RGB

def bgr_hsv(rgb_img):
    hsv_img = cv2.cvtColor(rgb_img, cv2.COLOR_RGB2HSV)
    return hsv_img

# %%
# image segmentation

# for extraction of green and brown color


def img_segmentation(rgb_img,hsv_img):
    lower_green = np.array([25,0,20])
    upper_green = np.array([100,255,255])
    healthy_mask = cv2.inRange(hsv_img, lower_green, upper_green)
    result = cv2.bitwise_and(rgb_img,rgb_img, mask=healthy_mask)
    lower_brown = np.array([10,0,10])
    upper_brown = np.array([30,255,255])
    disease_mask = cv2.inRange(hsv_img, lower_brown, upper_brown)
    disease_result = cv2.bitwise_and(rgb_img, rgb_img, mask=disease_mask)
    final_mask = healthy_mask + disease_mask
    final_result = cv2.bitwise_and(rgb_img, rgb_img, mask=final_mask)
    return final_result

# %%
# feature-descriptor-1: Hu Moments
def fd_hu_moments(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    feature = cv2.HuMoments(cv2.moments(image)).flatten()
    return feature

# %%
# feature-descriptor-2: Haralick Texture
def fd_haralick(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    haralick = mahotas.features.haralick(gray).mean(axis=0)
    return haralick

# %%
# feature-descriptor-3: Color Histogram
def fd_histogram(image, mask=None):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist  = cv2.calcHist([image], [0, 1, 2], None, [bins, bins, bins], [0, 256, 0, 256, 0, 256])
    cv2.normalize(hist, hist)
    return hist.flatten()

# %%
#Finding the correct leaf contour from the list of contours
def find_contour(cnts):
    contains = []
    y_ri,x_ri = n,m
    for cc in cnts:
        yn = cv2.pointPolygonTest(cc,(x_ri//2,y_ri//2),False)
        contains.append(yn)
        print(contains[0])
    val = [contains.index(temp) for temp in contains if temp>0]
   
    return val[0]

# %%
def create_dataset():
  names = ['isHealthy','mean_r','mean_g','mean_b','stddev_r','stddev_g','stddev_b', \
              'contrast','correlation','inverse_difference_moments','entropy']
  df = pd.DataFrame([], columns=names)
  for training_name in train_labels:
    
    # join the training data path and each species training folder
    dir = os.path.join(train_path, training_name)

    # get the current training label
    current_label = training_name

    # loop over the images in each sub-folder
    for x in range(1,images_per_class+1):
        # get the image file name
        file = dir + "/image (" + str(x) + ")"+ ".JPG"
        print(file)
        # file = dir + "/image (" + "84" + ")"+ ".JPG"
       
        # read the image and resize it to a fixed-size
        img = cv2.imread(file)
        img = cv2.resize(img, fixed_size)

        # #remove backgroud
        # img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        # gs = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
        # blur = cv2.GaussianBlur(gs, (25,25),0)
        # ret_otsu,im_bw_otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
        # kernel = np.ones((20,20),np.uint8)
        # closing = cv2.morphologyEx(im_bw_otsu, cv2.MORPH_CLOSE, kernel)

        # contours, hierarchy = cv2.findContours(closing,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        # cnt = contours[0]
        # plottedContour = cv2.drawContours(gs,contours,-1,(0,255,0),2)
        # n = img.shape[0]
        # m = img.shape[1]
        # print('shape ' + str(n) + ' ' + str(m))
        # black_img = np.empty([n,m,3],dtype=np.uint8)
        # black_img.fill(0)
        
        # index = find_contour(contours)
        # cnt = contours[index]
        # mask = cv2.drawContours(black_img, [cnt] , 0, (255,255,255), -1)  
    
        # maskedImg = cv2.bitwise_and(img, mask)

        # white_pix = [255,255,255]
        # black_pix = [0,0,0]
        # final_img = maskedImg
        # h,w,channels = final_img.shape
        # for x in range(0,w):
        #     for y in range(0,h):
        #         channels_xy = final_img[y,x]
        #         if all(channels_xy == black_pix):    
        #             final_img[y,x] = white_pix
    
        #Preprocessing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        gs = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
        blur = cv2.GaussianBlur(gs, (25,25),0)
        ret_otsu,im_bw_otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
        kernel = np.ones((50,50),np.uint8)
        closing = cv2.morphologyEx(im_bw_otsu, cv2.MORPH_CLOSE, kernel)

        final_img = img

        #get features
        #Color features
        red_channel = final_img[:,:,0]
        green_channel = final_img[:,:,1]
        blue_channel = final_img[:,:,2]
        blue_channel[blue_channel == 255] = 0
        green_channel[green_channel == 255] = 0
        red_channel[red_channel == 255] = 0
        
        red_mean = np.mean(red_channel)
        green_mean = np.mean(green_channel)
        blue_mean = np.mean(blue_channel)
        
        red_std = np.std(red_channel)
        green_std = np.std(green_channel)
        blue_std = np.std(blue_channel)
        
        #Texture features
        textures = mahotas.features.haralick(gs)
        ht_mean = textures.mean(axis=0)
        contrast = ht_mean[1]
        correlation = ht_mean[2]
        inverse_diff_moments = ht_mean[4]
        entropy = ht_mean[8]
        #write in csv

        vector = [training_name ,red_mean,green_mean,blue_mean,red_std,green_std,blue_std,\
                  contrast,correlation,inverse_diff_moments,entropy ]
        df_temp = pd.DataFrame([vector],columns=names)
        df = df.append(df_temp)
    print("[STATUS] processed folder: {}".format(current_label))

  print("[STATUS] completed Global Feature Extraction...")

  return df

# %%
dataset = create_dataset()
dataset.shape
dataset.to_csv("data.csv")
print("[STATUS] completed Global Feature Extraction...")
# Out:
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (1).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (2).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (3).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (4).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (5).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (6).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (7).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (8).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (9).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (10).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (11).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (12).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (13).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (14).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (15).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (16).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (17).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (18).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (19).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (20).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (21).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (22).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (23).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (24).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (25).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (26).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (27).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (28).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (29).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (30).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (31).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (32).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (33).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (34).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (35).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (36).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (37).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (38).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (39).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (40).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (41).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (42).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (43).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (44).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (45).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (46).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (47).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (48).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (49).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (50).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (51).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (52).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (53).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (54).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (55).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (56).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (57).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (58).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (59).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (60).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (61).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (62).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (63).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (64).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (65).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (66).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (67).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (68).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (69).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (70).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (71).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (72).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (73).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (74).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (75).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (76).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (77).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (78).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (79).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (80).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (81).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (82).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (83).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (84).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (85).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (86).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (87).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (88).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (89).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (90).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (91).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (92).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (93).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (94).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (95).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (96).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (97).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (98).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (99).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (100).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (101).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (102).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (103).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (104).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (105).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (106).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (107).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (108).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (109).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (110).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (111).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (112).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (113).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (114).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (115).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (116).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (117).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (118).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (119).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (120).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (121).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (122).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (123).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (124).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (125).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (126).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (127).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (128).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (129).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (130).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (131).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (132).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (133).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (134).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (135).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (136).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (137).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (138).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (139).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (140).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (141).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (142).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (143).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (144).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (145).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (146).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (147).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (148).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (149).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (150).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (151).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (152).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (153).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (154).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (155).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (156).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (157).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (158).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (159).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (160).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (161).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (162).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (163).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (164).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (165).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (166).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (167).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (168).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (169).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (170).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (171).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (172).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (173).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (174).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (175).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (176).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (177).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (178).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (179).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (180).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (181).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (182).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (183).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (184).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (185).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (186).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (187).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (188).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (189).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (190).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (191).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (192).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (193).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (194).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image (195).JPG
# /content/drive/My Drive/PATH_TO_OUTPUT/data/Black_rot/image